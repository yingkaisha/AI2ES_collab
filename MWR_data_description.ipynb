# %% [markdown]
# # AI2ES Data description

# %% [markdown]
# ### Proposed research
# * 1D neural-network-based bias-correction model
#
# ### Input
# * GEFS ensemble mean total precipitation (APCP; mm per 3 hours)
# * GEFS ensemble mean precipitable water (PWAT; mm per 3 hours)
# * Longitude
# * Latitude
# * Elevation
#
# ### Target
# * ERA5 total precipitation (mm per 3 hours)
#
# ### Data
# * Directory: `/glade/p/cisl/aiml/ksha/AI2ES/`
# * Data format: `xarray` saved as `zarr`
# * File naming convention: `ysha_GEFS_ERA5_BC_$year.zarr`, `year` ranges from 2000 to 2019

# %% [markdown]
# ### How to use this dataset

# %%
import xarray

# %%
DATA = xarray.open_zarr('/glade/p/cisl/aiml/ksha/AI2ES/ysha_GEFS_ERA5_BC_2000.zarr')

# %% [markdown]
# **Notes**
#
# * Checkout `Coordinates` and `Attributes`; they have everything you need.
# * Do not overwrite the original data files.

# %%
DATA
# Out:
# <xarray.Dataset>
# Dimensions:          (BC_land_latlon: 2574, fcst_lead: 54, initialization_day: 366)
# Coordinates:
#   * fcst_lead        (fcst_lead) float64 9.0 12.0 15.0 ... 162.0 165.0 168.0
#     lat              (BC_land_latlon) float64 dask.array<chunksize=(2574,), meta=np.ndarray>
#     lon              (BC_land_latlon) float64 dask.array<chunksize=(2574,), meta=np.ndarray>
# Dimensions without coordinates: BC_land_latlon, initialization_day
# Data variables:
#     Input_GEFS_APCP  (initialization_day, fcst_lead, BC_land_latlon) float64 dask.array<chunksize=(46, 7, 644), meta=np.ndarray>
#     Input_GEFS_PWAT  (initialization_day, fcst_lead, BC_land_latlon) float64 dask.array<chunksize=(46, 7, 644), meta=np.ndarray>
#     Input_elevation  (BC_land_latlon) float64 dask.array<chunksize=(2574,), meta=np.ndarray>
#     Input_land_lat   (BC_land_latlon) float64 dask.array<chunksize=(2574,), meta=np.ndarray>
# ...
